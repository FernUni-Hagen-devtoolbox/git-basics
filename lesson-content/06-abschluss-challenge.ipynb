# %% [markdown]
# ## Git Basics: Notebook 06 · TaskFlow-Abschluss-Challenge
#
# Sie bereiten einen Beitrag für TaskFlow 0.2.0 vor. Dabei korrigieren Sie Dokumentation, ergänzen eine ausführbare Versionsoption und führen Sams parallelen Beitrag nach einer Prüfrückmeldung mit Ihrer Arbeit zusammen.
#
# **Voraussetzungen:** Sie haben die fünf Lernpfad-Abschnitte und ihre praktischen Übungen bearbeitet. Lesen Sie zuerst die HTML-Seite zur Abschluss-Challenge.
#
# **Zeitbedarf:** Etwa 100 bis 130 Minuten. Nach der ersten Prüfanfrage bietet sich eine Pause an.

# %% [markdown]
# ### Arbeit in MyBinder
#
# Wenn Sie die Challenge über den vorgesehenen MyBinder-Link öffnen, sehen Sie links dieses Notebook und rechts ein vorbereitetes Terminal. Bearbeiten Sie die gesamte Challenge in MyBinder.
#
# Alle Zellen enthalten Markdown. Befehlsblöcke werden im Terminal eingegeben. Die sieben Aufgaben nennen die gewünschten Ergebnisse. Versuchen Sie zunächst selbst, passende Git-Befehle zu wählen. Nur die Musterlösungen sind ausklappbar. Halten Sie Ihre Beobachtungen in den vorgesehenen Markdown-Zellen fest. Zum Bearbeiten einer solchen Zelle können Sie sie doppelt anklicken und danach mit Umschalt + Enter wieder anzeigen.
#
# Bereiten Sie den unabhängigen Teamstand vor:
#
# ```bash
# cd ~
# bash scripts/prepare-taskflow-final.sh
# cd taskflow-abschluss-challenge
# ```
#
# Die Vorbereitung erstellt `team.git`, `sam-team.git` und Sams Arbeitskopie `sam`. Ihre eigene Arbeitskopie `mein-taskflow` legen Sie in Aufgabe 1 selbst an. Ein vorhandener Challenge-Ordner wird nicht überschrieben. Für einen neuen Durchlauf können Sie der Vorbereitung einen anderen Ordnernamen als Argument mitgeben und anschließend in diesen Ordner wechseln. Die späteren relativen Pfade bleiben gleich.

# %% [markdown]
# ### Miras Auftrag und die Erfolgskriterien
#
# Das bereitgestellte Python-Beispiel liest `aufgaben.json`. Es zeigt eine offene und eine erledigte Lernaufgabe an. Die erledigte Aufgabe bleibt gespeichert. Die README behauptet dagegen, dass sie automatisch gelöscht werde. Im Changelog wird behauptet, dass `--version` schon in 0.1.0 verfügbar sei. Diese Option funktioniert im Ausgangsstand noch nicht.
#
# Das fertige Ergebnis soll:
#
# - Speicherung und Anzeige erledigter Aufgaben korrekt erklären
# - den falschen Changelog-Eintrag korrigieren und seinen ursprünglichen geteilten Commit erhalten
# - mit `--version` die Ausgabe `TaskFlow 0.2.0` liefern
# - beim normalen Aufruf weiterhin beide vorbereiteten Aufgaben anzeigen und ihre Datei unverändert lassen
# - die neue Versionsbedienung in der README und die Änderung unter 0.2.0 im Changelog dokumentieren
# - Sams Hinweis auf den gemeinsamen Wochenrückblick berücksichtigen
# - bereits geteilte eigene Beiträge und Sams Beitrag unter ihren bisherigen Kennungen erhalten
# - erst nach einer begründeten Freigabe für den aktuellen Beitrag im Teamhauptzweig stehen
#
# Sie benötigen kein Plattformkonto und müssen kein vollständiges Aufgabenprogramm entwickeln. Die kleinen Programmänderungen unterstützt eine Hilfe. Ihre Dokumentation darf eigene verständliche Formulierungen verwenden.

# %% [markdown]
# ### Hilfen für Programm und Teamrollen
#
# Die folgenden Aufrufe dienen der bereitgestellten Umgebung. Sie ersetzen Ihre eigenen Entscheidungen zum Git-Ablauf nicht. Führen Sie sie erst in der angegebenen Etappe aus. Ab Aufgabe 2 bleiben Sie in `mein-taskflow`.
#
# **Programm untersuchen und testen:**
#
# ```bash
# python3 taskflow.py
# python3 taskflow.py --version
# python3 taskflow.py --help
# ```
#
# Im Ausgangsstand wird `--version` mit einer Fehlermeldung abgelehnt. Nach Ihrer Implementierung soll dieser Aufruf erfolgreich sein. Der normale Aufruf soll in beiden Ständen zeigen:
#
# ```text
# Offen: Übungsblatt Programmierung bearbeiten
# Erledigt: Lerntermin vereinbaren
# ```
#
# **Aufgabe 3: Versionsoption bereitstellen.** Vorher muss Ihr Arbeitsbranch sauber sein. Die Hilfe ändert nur `taskflow.py` und `version.txt`. Sie erstellt keinen Commit und teilt nichts:
#
# ```bash
# bash ~/scripts/add-taskflow-version.sh
# ```
#
# **Aufgaben 4 und 6: Miras Review nachbilden.** Die Hilfe zeigt Quelle, Ziel, Kennungen, neue Commits und den Dateivergleich aus `team.git`. Sie übernehmen Miras Rolle und geben eine Entscheidung sowie eine begründete Rückmeldung ein:
#
# ```bash
# bash ~/scripts/review-taskflow-collaboration.sh .. feature/version
# ```
#
# Mit `überarbeiten` dokumentieren Sie eine noch notwendige Überarbeitung. Mit `freigeben` dokumentieren Sie die Freigabe. Die Hilfe schreibt `review.txt` im Challenge-Ordner außerhalb des Projekts. Sie prüft keine fachliche Richtigkeit und integriert keinen Branch. Bewahren Sie die Erstprüfung in Aufgabe 4 als `review-erstpruefung.txt` im selben Ordner auf. Beim zweiten Review wird `review.txt` durch die neue Rückmeldung ersetzt.
#
# **Aufgabe 5: Sams Beitrag veröffentlichen.** Die Hilfe erwartet die dokumentierte Erstprüfung mit notwendiger Überarbeitung. Sie ändert nur Sams Arbeitskopie und veröffentlicht seinen Branch in `sam-team.git`. Ihr Arbeitsbranch und `team.git/main` bleiben unverändert:
#
# ```bash
# bash ~/scripts/simulate-taskflow-final.sh ..
# ```
#
# **Aufgabe 7: Den geteilten Abschlussstand prüfen.** Die Kontrolle verwendet die Dateien aus dem tatsächlich veröffentlichten Commit:
#
# ```bash
# python3 ~/scripts/check-taskflow-final.py ..
# ```
#
# Die Hilfen liegen im Binder-Ordner [scripts](scripts/). Fehlerhinweise bedeuten, dass der benötigte Ausgangsstand noch nicht erreicht ist. Prüfen Sie diesen Stand, bevor Sie weitermachen.

# %% [markdown]
# ### Aufgabe 1: Arbeitskopie und Ausgangsstand untersuchen
#
# Sie stehen im Challenge-Ordner.
#
# 1. Legen Sie aus `team.git` Ihre Arbeitskopie `mein-taskflow` an und wechseln Sie hinein.
# 2. Prüfen Sie Name und E-Mail für Ihre Commit-Kennzeichnung. Verwenden Sie für diese Übung fiktive Angaben. Richten Sie Nano als Commit-Editor ein.
# 3. Untersuchen Sie aktuellen Branch, Arbeitsstatus, Remote-Verbindung und Upstream-Zuordnung.
# 4. Lesen Sie die sechs Projektdateien und die drei geteilten Startcommits. Welcher Commit hat den falschen Changelog-Eintrag eingeführt?
# 5. Vergleichen Sie README und Changelog mit dem tatsächlich ausgeführten Programm. Prüfen Sie auch, ob die Aufgaben nach den Aufrufen weiterhin in ihrer Datei stehen.
#
# **Ergebnis:** Eine saubere Arbeitskopie auf `main` mit nachvollzogenem Ausgangsstand. Noch keine Projektänderung.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# git clone team.git mein-taskflow
# cd mein-taskflow
# git config user.name "Kim Beispiel"
# git config user.email "kim@taskflow.example"
# git config core.editor nano
# git status
# git branch -vv
# git remote -v
# git log --oneline --decorate
# git show HEAD
# cat README.md CHANGELOG.md TEAM.md version.txt taskflow.py aufgaben.json
# ```
#
# Prüfen Sie außerdem die Programmaufrufe aus der Hilfe. `main` und `origin/main` zeigen auf den dritten Startcommit. Der Upstream von `main` ist `origin/main`. Die Remote-Verbindung führt zur bereitgestellten Austauschstelle `team.git`.
#
# Der jüngste Commit von Sam fügt die falsche Aussage zur Versionsoption ein. Die README-Aussage stammt schon aus dem ersten Commit. Notieren Sie die tatsächlichen Kennungen. Die Aufgabenanzeige widerspricht der Löschbehauptung und der Versionsaufruf wird noch abgelehnt.
#
# </details>

# %% [markdown]
# ### Ihre Beobachtungen zum Ausgangsstand
#
# - Kennung des geteilten Ausgangsstands:
# - Kennung und Inhalt des falschen Changelog-Commits:
# - Branch und Upstream:
# - Widerspruch zwischen README und Programm:
# - Ergebnis des Versionsaufrufs und Zustand der Aufgabendatei:

# %% [markdown]
# ### Aufgabe 2: Die Dokumentationsfehler nachvollziehbar korrigieren
#
# 1. Bereiten Sie Ihre Korrekturen auf `bugfix/dokumentation` vor.
# 2. Machen Sie die unzutreffende Changelog-Ergänzung mit einem neuen nachvollziehbaren Korrekturschritt rückgängig. Der schon geteilte ursprüngliche Commit muss erhalten bleiben.
# 3. Korrigieren Sie anschließend die README. Erledigte Aufgaben bleiben gespeichert und werden weiterhin angezeigt. Halten Sie diese Korrektur als eigenen sinnvollen Arbeitsschritt fest.
# 4. Notieren Sie die Kennung Ihres letzten eigenen noch nicht geteilten README-Commits. Präzisieren Sie seine Nachricht durch Ersetzen dieses letzten Commits und vergleichen Sie die neue Kennung.
# 5. Prüfen Sie die Historie und den Arbeitsstatus. Erklären Sie, weshalb Sie den geteilten Changelog-Commit anders behandelt haben als Ihren eigenen letzten Commit.
#
# **Ergebnis:** Beide Aussagen sind korrigiert. Der ursprüngliche Teamstand bleibt erreichbar. `main` bleibt unverändert und Ihre Korrekturen sind noch nicht geteilt.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# git switch -c bugfix/dokumentation
# git revert --no-edit HEAD
# nano README.md
# ```
#
# Eine mögliche README lautet:
#
# ```text
# # TaskFlow
#
# TaskFlow verwaltet Lernaufgaben für das Studium.
# Erledigte Aufgaben bleiben gespeichert und werden weiterhin angezeigt.
# ```
#
# Erstellen Sie Ihren eigenen Commit und präzisieren Sie anschließend seine Nachricht:
#
# ```bash
# git add README.md
# git commit -m "README aktualisieren"
# git rev-parse HEAD
# git commit --amend -m "Speicherung erledigter Aufgaben korrekt beschreiben"
# git rev-parse HEAD
# git log --graph --oneline --decorate --all
# git status
# ```
#
# Die zwei Kennungen des letzten eigenen Commits unterscheiden sich. Seine neue Nachricht beschreibt die fertige Änderung genauer. Dieser Beitrag war noch nicht geteilt. Der neue Revert-Commit erhält dagegen den schon geteilten ursprünglichen Changelog-Commit als Vorgänger und nimmt dessen Änderung zurück.
#
# Bei diesem Ablauf enthält der Korrekturbranch fünf erreichbare Commits. `main` steht weiterhin beim dritten Startcommit. Der Arbeitsstand ist sauber.
#
# </details>

# %% [markdown]
# ### Ihr Nachweis zu Undo und Commit-Nachrichten
#
# - Kennung des eigenen letzten Commits vor dem Ersetzen:
# - Kennung danach:
# - Warum durfte dieser eigene Commit ersetzt werden?
# - Wie bleibt die geteilte fehlerhafte Änderung nachvollziehbar?

# %% [markdown]
# ### Aufgabe 3: Versionsoption und Dokumentation ergänzen
#
# 1. Beginnen Sie `feature/version` von Ihrem korrigierten Dokumentationsstand aus.
# 2. Stellen Sie die Versionsoption mit der Implementierungshilfe bereit. Untersuchen Sie die beiden geänderten Dateien und prüfen Sie die tatsächlichen Programmaufrufe.
# 3. Halten Sie die zusammengehörige Programmänderung und die neue Versionsnummer als einen Arbeitsschritt fest.
# 4. Dokumentieren Sie die Versionsbedienung in der README und die neue Option unter 0.2.0 im Changelog. Halten Sie diese Dokumentationsänderung als zweiten Arbeitsschritt fest.
# 5. Prüfen Sie Status, Historie und den unveränderten Hauptzweig.
#
# **Ergebnis:** `--version` liefert `TaskFlow 0.2.0`. Die normale Anzeige bleibt erhalten. Programmänderung und Dokumentation sind getrennte sinnvolle Commits. Noch wurde nichts geteilt.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# git switch -c feature/version
# bash ~/scripts/add-taskflow-version.sh
# git diff
# python3 taskflow.py --version
# python3 taskflow.py
# git add taskflow.py version.txt
# git commit -m "Versionsausgabe für TaskFlow 0.2.0 ergänzen"
# nano README.md
# nano CHANGELOG.md
# ```
#
# Ergänzen Sie die README beispielsweise um:
#
# ```text
# ## Versionsausgabe
# Mit python3 taskflow.py --version wird die Programmversion angezeigt.
# Die aktuelle Ausgabe lautet TaskFlow 0.2.0.
# ```
#
# Der neue Changelog-Abschnitt kann so aussehen:
#
# ```text
# ## 0.2.0
# Die Option --version zeigt die aktuelle Programmversion an.
# ```
#
# Setzen Sie ihn oberhalb von 0.1.0 ein. Dessen falsche Versionsbehauptung soll bereits entfernt sein.
#
# ```bash
# git diff
# git diff --check
# git add README.md CHANGELOG.md
# git diff --staged
# git commit -m "Versionsbedienung und neue Änderung dokumentieren"
# git status
# git log --graph --oneline --decorate --all
# ```
#
# Beim beschriebenen Ablauf enthält `feature/version` sieben erreichbare Commits. `bugfix/dokumentation` steht nach den Korrekturen bei fünf und `main` beim Ausgangsstand mit drei. Die Versionsdatei allein wäre kein Nachweis. Entscheidend ist die erfolgreiche Ausführung der neuen Option.
#
# </details>

# %% [markdown]
# ### Aufgabe 4: Die erste Prüfanfrage stellen
#
# 1. Teilen Sie beide Arbeitsbranches in `team.git` und richten Sie ihre Upstream-Zuordnungen ein. Der Teamhauptzweig bleibt beim Ausgangsstand.
# 2. Formulieren Sie eine kurze Prüfanfrage: Quelle `feature/version`, Ziel `main`, Korrekturen, neue Funktion und bisherige Prüfungen.
# 3. Starten Sie die Review-Hilfe. Prüfen Sie den tatsächlich veröffentlichten Beitrag in Miras Rolle. Der gemeinsame Wochenrückblick fehlt noch. Dokumentieren Sie daher eine notwendige Überarbeitung und begründen Sie, was ergänzt werden soll.
# 4. Bewahren Sie diese Erstprüfung als `review-erstpruefung.txt` außerhalb des Projekts auf. Notieren Sie die geprüften Quell- und Zielkennungen.
#
# **Ergebnis:** Ihre Beiträge sind geteilt. Eine begründete Rückmeldung zur Überarbeitung liegt vor. Die Veröffentlichung allein hat weder eine Freigabe noch eine Aufnahme in `main` bewirkt.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# git push -u origin bugfix/dokumentation
# git push -u origin feature/version
# git fetch origin
# git branch -vv
# git log --oneline origin/main..origin/feature/version
# git diff origin/main origin/feature/version
# bash ~/scripts/review-taskflow-collaboration.sh .. feature/version
# ```
#
# Eine mögliche Prüfanfrage: „Bitte prüfen Sie `feature/version` für die Aufnahme in `main`. Der Beitrag korrigiert die Speicherung erledigter Aufgaben und den früheren Changelog-Eintrag. Er ergänzt und dokumentiert die Versionsausgabe. Versionsaufruf und normale Aufgabenanzeige wurden geprüft.“
#
# Geben Sie in Miras Rolle `überarbeiten` ein. Eine passende Rückmeldung benennt den fehlenden gemeinsamen Wochenrückblick und bittet um die Integration von Sams Parallelbeitrag. Prüfen Sie die angezeigten Dateien tatsächlich, bevor Sie die Rückmeldung formulieren.
#
# ```bash
# cp ../review.txt ../review-erstpruefung.txt
# cat ../review-erstpruefung.txt
# ```
#
# Die Rückmeldung nennt den geteilten Versionsbranch als Quelle und den unveränderten Teamhauptzweig als Ziel. Beim Musterablauf sind das die Stände mit sieben beziehungsweise drei erreichbaren Commits. Die Kopie bewahrt nur die erste Rückmeldung innerhalb Ihrer Binder-Arbeitsumgebung. Sie gehört nicht zu den Projektdateien.
#
# </details>

# %% [markdown]
# ### Ihre Prüfanfrage und Erstprüfung
#
# - Prüfanfrage in eigenen Worten:
# - Geteilter Quellbranch und Kennung:
# - Zielbranch und Kennung:
# - Begründete Rückmeldung zur Überarbeitung:
# - Woran erkennen Sie, dass der Beitrag noch nicht aufgenommen wurde?

# %% [markdown]
# ### Aufgabe 5: Sams Parallelbeitrag holen und zusammenführen
#
# 1. Stellen Sie Sams Beitrag mit der Simulationshilfe bereit. Er liegt auf `docs/wochenrueckblick` in `sam-team.git`.
# 2. Verbinden Sie diese Austauschstelle als zweiten Remote mit Ihrer Arbeitskopie. Holen Sie den Beitrag und vergleichen Sie ihn mit Ihrer Arbeit. Notieren Sie Sams Commit-Kennung.
# 3. Prüfen Sie, welche Verweise durch das Holen geändert wurden und ob Ihr Arbeitsbranch oder seine Dateien bereits integriert wurden.
# 4. Führen Sie Sams Beitrag mit `feature/version` zusammen. Ihre bereits geteilten Beiträge und Sams Commit müssen ihre Kennungen behalten.
# 5. Lösen Sie den README-Konflikt anhand der fachlichen Vorgabe: Erledigte Aufgaben bleiben gespeichert und sichtbar. Das Lernteam bespricht sie beim Wochenrückblick gemeinsam. Die neue Versionsbedienung bleibt ebenfalls dokumentiert.
# 6. Prüfen Sie den fertigen Dateistand und das Programm. Schließen Sie die Integration ab.
#
# **Ergebnis:** Beide Beiträge sind unter ihren bisherigen Kennungen verbunden. Der Arbeitsstand ist sauber. Der Teamhauptzweig ist weiterhin unverändert.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# bash ~/scripts/simulate-taskflow-final.sh ..
# git remote add sam ../sam-team.git
# git fetch sam
# git log --graph --oneline --decorate --all
# git rev-parse sam/docs/wochenrueckblick
# git diff HEAD sam/docs/wochenrueckblick -- README.md
# git status
# git merge sam/docs/wochenrueckblick
# ```
#
# Das Holen aktualisiert `sam/main` und `sam/docs/wochenrueckblick`. Ihr eigener Versionsbranch und die Dateien bleiben dabei zunächst unverändert. Der anschließende Merge hält mit einem Konflikt in `README.md` an.
#
# ```bash
# git status
# git diff --name-only --diff-filter=U
# nano README.md
# ```
#
# Entfernen Sie die Konfliktmarker und formulieren Sie eine gemeinsame Lösung. Eine mögliche vollständige README lautet:
#
# ```text
# # TaskFlow
#
# TaskFlow verwaltet Lernaufgaben für das Studium.
# Erledigte Aufgaben bleiben gespeichert und werden weiterhin angezeigt.
# Das Lernteam bespricht erledigte Aufgaben beim Wochenrückblick gemeinsam.
#
# ## Versionsausgabe
# Mit python3 taskflow.py --version wird die Programmversion angezeigt.
# Die aktuelle Ausgabe lautet TaskFlow 0.2.0.
# ```
#
# Prüfen Sie auch die anderen Dateien und die Laufzeit:
#
# ```bash
# git diff --check
# python3 taskflow.py --version
# python3 taskflow.py
# git add README.md
# git diff --staged
# git diff --name-only --diff-filter=U
# git commit -m "Wochenrückblick mit korrekter Aufgabenanzeige verbinden"
# git status
# git log --graph --oneline --decorate --all
# ```
#
# Beim Musterablauf hat der Merge-Commit zwei Eltern und neun erreichbare Commits. Ihr bisher geteilter Versionsbeitrag und Sams Commit bleiben erhalten. Ein Rebase Ihrer bereits geteilten Arbeitscommits würde die geforderte gemeinsame Grundlage ersetzen. Bei noch nicht geteilter Arbeit und einer gewünschten linearen Historie könnte Rebase passen.
#
# </details>

# %% [markdown]
# ### Ihr Nachweis zur Zusammenarbeit
#
# - Kennung von Sams geteiltem Commit:
# - Wirkung des Holens auf Verweise und Arbeitsdateien:
# - Widerspruch der beiden README-Fassungen:
# - Fachliche Begründung Ihrer gemeinsamen Lösung:
# - Gewähltes Integrationsverfahren und Begründung:

# %% [markdown]
# ### Aufgabe 6: Die überarbeitete Lösung prüfen und aufnehmen
#
# 1. Ergänzen Sie einen eigenen hilfreichen README-Hinweis als weiteren sinnvollen Arbeitsschritt. Ein Minimalbeispiel ist ein Hinweis darauf, dass die Aufgabenanzeige die gespeicherte Liste nicht verändert. Ihre Formulierung darf anders lauten.
# 2. Prüfen Sie die Versionsausgabe, die normale Anzeige, die erhaltenen Aufgaben, die Dokumentation und die Historie.
# 3. Teilen Sie den überarbeiteten Versionsbranch durch Fortschreiben seines bisherigen geteilten Stands. Keine bisher geteilte Kennung soll ersetzt werden.
# 4. Starten Sie den Review erneut und übernehmen Sie Miras Rolle. Vergleichen Sie alle Erfolgskriterien mit dem veröffentlichten Dateistand. Dokumentieren Sie eine begründete Freigabe, wenn diese Kriterien erfüllt sind. Falls noch etwas fehlt, korrigieren Sie den Beitrag und wiederholen Sie die Prüfung.
# 5. Vergleichen Sie vor der Aufnahme die aktuellen geteilten Quell- und Zielkennungen mit der Freigabe. Bei einer Abweichung ist eine erneute Prüfung nötig.
# 6. Nehmen Sie erst den freigegebenen Beitrag in `main` auf und teilen Sie diesen Hauptzweig. Behalten Sie Ihre Arbeitsbranches für den Nachweis.
#
# **Ergebnis:** Der überarbeitete Versionsbranch und der Teamhauptzweig enthalten denselben freigegebenen Stand. Ihre Arbeitskopie steht sauber auf `main`. Die Erstprüfung bleibt als eigene Rückmeldung erhalten.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# nano README.md
# ```
#
# Ein möglicher zusätzlicher Satz: „Die Aufgabenanzeige verändert die gespeicherte Aufgabenliste nicht.“ Prüfen Sie den Hinweis am Programm und an `aufgaben.json`.
#
# ```bash
# git diff
# git diff --check
# python3 taskflow.py --version
# python3 taskflow.py
# cat aufgaben.json
# git add README.md
# git commit -m "Unveränderte Aufgabenliste bei der Anzeige erläutern"
# git push
# bash ~/scripts/review-taskflow-collaboration.sh .. feature/version
# ```
#
# Prüfen Sie den angezeigten Beitrag. Geben Sie bei erfüllten Kriterien `freigeben` ein und begründen Sie die Entscheidung. Die Rückmeldung sollte die korrigierte Speicherung, die tatsächliche Versionsfunktion, die Dokumentation und den integrierten Wochenrückblick berücksichtigen.
#
# ```bash
# git fetch origin
# git rev-parse origin/feature/version origin/main
# cat ../review.txt
# ```
#
# Vergleichen Sie die beiden Kennungen in derselben Reihenfolge mit `Quellcommit` und `Zielcommit` im Review. Stimmen sie überein, kann die Aufnahme erfolgen:
#
# ```bash
# git switch main
# git pull --ff-only origin main
# git merge --ff-only origin/feature/version
# git push origin main
# git status
# git branch -vv
# git log --graph --oneline --decorate --all
# ```
#
# Beim beschriebenen Ablauf hat der freigegebene Stand zehn erreichbare Commits. Der vorherige `main` ist dessen Vorgänger. Die Aufnahme kann deshalb per Fast-Forward erfolgen. Auch der überarbeitete Versionsbranch baut auf seinem zuerst geteilten Stand auf. Für beide Veröffentlichungen ist ein normaler Push möglich.
#
# Ein Fast-Forward erzeugt keinen zusätzlichen Merge-Commit. Der schon vorhandene Konflikt-Merge bleibt Teil der Historie. `bugfix/dokumentation` bleibt beim korrigierten Zwischenstand.
#
# </details>

# %% [markdown]
# ### Ihre Freigabe und Aufnahme
#
# - Eigener zusätzlicher Hinweis und sein Nutzen:
# - Geprüfter Quellcommit der Freigabe:
# - Geprüfter Zielcommit vor der Aufnahme:
# - Begründung der Freigabe in Miras Rolle:
# - Kennung des Teamhauptzweigs nach der Aufnahme:
# - Warum konnten Sie die beiden geteilten Branches normal fortschreiben?

# %% [markdown]
# ### Aufgabe 7: Den Abschluss belegen und reflektieren
#
# 1. Führen Sie die technische Abschlusskontrolle aus Ihrer Arbeitskopie auf `main` aus. Lesen Sie bei einem Fehler den Hinweis und prüfen Sie den genannten Zustand.
# 2. Halten Sie die geprüfte Hauptzweig-Kennung und das Ergebnis der Kontrolle unten fest.
# 3. Belegen Sie anhand Ihrer Historie, dass der ursprüngliche Teamstand, der zuerst geteilte Versionsbeitrag und Sams Beitrag unter ihren bisherigen Kennungen erhalten sind.
# 4. Beantworten Sie die Reflexionsfragen in eigenen Worten. Die technische Kontrolle ersetzt diese Begründungen nicht.
#
# **Ergebnis:** Ein tatsächlich geteilter funktionsfähiger Stand, zwei nachvollziehbare Review-Rückmeldungen und Ihre begründete Reflexion.

# %% [markdown]
# <details>
# <summary>Mögliche Lösung und Beobachtungen anzeigen</summary>
#
# ```bash
# python3 ~/scripts/check-taskflow-final.py ..
# git log --graph --oneline --decorate --all
# git rev-parse HEAD origin/main origin/feature/version
# ```
#
# Die Kontrolle soll „Technische Abschlusskontrolle erfolgreich.“ melden. Die drei zuletzt ausgegebenen Kennungen sollen übereinstimmen.
#
# Prüfen Sie Ihre drei früher notierten Kennungen jeweils mit:
#
# ```bash
# git merge-base --is-ancestor <notierte-kennung> main
# echo $?
# ```
#
# Ersetzen Sie den Platzhalter durch die tatsächliche Kennung des Ausgangsstands, des zuerst geteilten Versionsbeitrags oder von Sams Beitrag. Der erste Befehl bleibt bei Erfolg still. `echo $?` zeigt für den unmittelbar vorherigen Befehl den Rückgabewert `0`, wenn die Kennung ein Vorgänger von `main` ist. Die ersetzte alte Kennung Ihres eigenen noch nicht geteilten README-Commits gehört dagegen nicht zur fertigen Hauptzweig-Historie.
#
# Die Abschlusskontrolle prüft die gemeinsamen Stände, ihre Vorgänger und die Zuordnung der dokumentierten Reviews. Sie führt `--version` und die normale Aufgabenanzeige mit den Dateien aus dem veröffentlichten Commit aus. Eine bloß im Arbeitsverzeichnis ergänzte ungeteilte Funktion reicht deshalb nicht. Verständlichkeit, fachliche Dokumentationsaussagen und Ihre Begründungen werden separat anhand der Aufgaben beurteilt.
#
# </details>

# %% [markdown]
# ### Ihr Abschlussnachweis und Ihre Reflexion
#
# - Geprüfte Kennung des Teamhauptzweigs:
# - Ergebnis der technischen Abschlusskontrolle:
# - Nachweise zu den drei erhaltenen geteilten Kennungen:
#
# Beantworten Sie außerdem:
#
# 1. Warum war ein neuer Korrekturcommit für den alten Changelog-Fehler passend? Warum war das Ersetzen Ihrer eigenen letzten Commit-Nachricht vor dem Teilen möglich?
# 2. Was unterscheidet das Holen, das Teilen eines Arbeitsbranches, seine Prüfung und seine Aufnahme in den Hauptzweig?
# 3. Warum war es nötig, die README fachlich zu prüfen, statt nur die Konfliktmarker zu entfernen?
# 4. Welche Vor- und Nachteile hatte Ihr Integrationsverfahren hier? Unter welchen geänderten Voraussetzungen würden Sie Rebase wählen?
# 5. Wie stellen Sie sicher, dass eine Freigabe zu den tatsächlich aufgenommenen Inhalten gehört?
# 6. Was bestätigt die ausgeführte technische Kontrolle und was muss weiterhin fachlich beurteilt werden?
#
# Die Challenge ist abgeschlossen, wenn sowohl die technische Kontrolle als auch die fachlichen Erfolgskriterien erfüllt sind und Ihre Begründungen vorliegen. Ihre Projektstände, Review-Rückmeldungen und Notizen bleiben Teil der Arbeit in dieser Binder-Umgebung.
